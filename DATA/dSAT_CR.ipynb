# %%
import pandas as pd

# Load the provided Excel file to examine its contents
file_path = 'DATA dSAT2.xlsx'
xls = pd.ExcelFile(file_path)

# Check the sheet names to identify where the "Tidy" data is located
xls.sheet_names


# Load the 'Tidy' sheet to analyze the data
df_tidy = pd.read_excel(file_path, sheet_name='Tidy')

# Display the first few rows of the dataset to understand its structure
df_tidy.head()
# Out:
#    Column1 Phenotype  Animal_No  Stimulus_Duration Distractor_Condition  \
# 0       51        ST      377.0                 25                  SAT
# 1       99        ST      377.0                 25                 dSAT
# 2      147        ST      377.0                 50                  SAT
# 3      219        ST      377.0                 50                 dSAT
# 4      294        ST      377.0                500                  SAT
#
#        HITS    MISSES        FA         CR        OM
# 0  1.000000  5.333333  0.916667  19.083333  0.166667
# 1  1.625000  5.375000       NaN        NaN  0.000000
# 2  2.166667  4.583333       NaN        NaN  0.000000
# 3  1.500000  5.875000  3.750000  16.500000  0.000000
# 4  3.944444  2.333333       NaN        NaN  0.166667

# %%
import pandas as pd
from pingouin import mixed_anova, pairwise_tests

# Load your data
file_path = 'DATA dSAT2.xlsx'
xls = pd.ExcelFile(file_path)
tidy_df = pd.read_excel(file_path, sheet_name='Tidy')

# Clean the data and focus on the relevant columns
tidy_df_clean = tidy_df.dropna(subset=['CR'])
tidy_df_clean = tidy_df_clean.rename(columns={'Distractor_Condition': 'Condition', 'Animal_No': 'Animal', 'CR': 'CorrectRejection'})

# Conduct a mixed-design ANOVA
anova_results = mixed_anova(dv='CorrectRejection', between='Phenotype', within='Condition', subject='Animal', data=tidy_df_clean)

# Post-hoc pairwise comparisons with Bonferroni correction
post_hoc_results = pairwise_tests(dv='CorrectRejection', between='Phenotype', within='Condition', subject='Animal', data=tidy_df_clean, padjust='bonf')

# Calculate generalized eta-squared for effect size
anova_results['generalized_eta_squared'] = anova_results['np2'] / (1 - anova_results['np2'] + (len(tidy_df_clean) - 1))

print(anova_results)
print(post_hoc_results)
# Out:
#         Source          SS  DF1  DF2          MS          F         p-unc  \
# 0    Phenotype    5.476076    2   37    2.738038   0.374886  6.899488e-01
# 1    Condition  230.218821    1   37  230.218821  69.481396  5.117118e-10
# 2  Interaction    1.345856    2   37    0.672928   0.203094  8.171056e-01
#
#         np2  eps  generalized_eta_squared
# 0  0.019862  NaN                 0.000248
# 1  0.652521  1.0                 0.008224
# 2  0.010859  NaN                 0.000136
#                 Contrast Condition    A     B Paired Parametric         T  \
# 0              Condition         -  SAT  dSAT   True       True  8.511279
# 1              Phenotype         -   GT    IN  False       True  0.265177
# 2              Phenotype         -   GT    ST  False       True -0.615666
# 3              Phenotype         -   IN    ST  False       True -0.744905
# 4  Condition * Phenotype       SAT   GT    IN  False       True  1.032780
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# First, ensure the data is clean and ready for visualization
tidy_df_clean = tidy_df.dropna(subset=['CR'])
tidy_df_clean = tidy_df_clean.rename(columns={'Distractor_Condition': 'Condition', 'Animal_No': 'Animal', 'CR': 'CorrectRejection'})

# Set up the plot aesthetics
sns.set(style="whitegrid")

# Create a figure for the bar plots of main effects
plt.figure(figsize=(10, 6))

# 1. Main Effect of Phenotype
plt.subplot(1, 2, 1)
sns.barplot(x="Phenotype", y="CorrectRejection", data=tidy_df_clean, ci='sd')
plt.title("Main Effect of Phenotype on False Alarms")
plt.ylabel("False Alarm Rate")
plt.xlabel("Phenotype")

# 2. Main Effect of Distractor Condition
plt.subplot(1, 2, 2)
sns.barplot(x="Condition", y="CorrectRejection", data=tidy_df_clean, ci='sd')
plt.title("Main Effect of Condition on False Alarms")
plt.ylabel("CR Rate")
plt.xlabel("Condition")

plt.tight_layout()
plt.show()

# Now create an interaction plot
plt.figure(figsize=(8, 6))
sns.pointplot(x="Condition", y="CorrectRejection", hue="Phenotype", data=tidy_df_clean, ci='sd', dodge=True, markers=["o", "s"], capsize=0.1)
plt.title("Interaction Plot: Phenotype and Condition")
plt.ylabel("CR Rate")
plt.xlabel("Condition")
plt.legend(title="Phenotype")
plt.show()
# Out:
# C:\Users\pfh3221\AppData\Local\Temp\ipykernel_4932\3540170753.py:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x="Phenotype", y="CorrectRejection", data=tidy_df_clean, ci='sd')
# C:\Users\pfh3221\AppData\Local\Temp\ipykernel_4932\3540170753.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x="Condition", y="CorrectRejection", data=tidy_df_clean, ci='sd')
# C:\Users\pfh3221\AppData\Local\Temp\ipykernel_4932\3540170753.py:33: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.pointplot(x="Condition", y="CorrectRejection", hue="Phenotype", data=tidy_df_clean, ci='sd', dodge=True, markers=["o", "s"], capsize=0.1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 33
# ...

# %%
# Fixing the interaction plot without specifying markers explicitly
plt.figure(figsize=(8, 6))
sns.pointplot(x="Condition", y="CorrectRejection", hue="Phenotype", data=tidy_df_clean, ci='sd', dodge=True, capsize=0.1)
plt.title("Interaction Plot: Phenotype and Condition")
plt.ylabel("CR Rate")
plt.xlabel("Condition")
plt.legend(title="Phenotype")
plt.ylim(0, 20) 
plt.show()
# Out:
# C:\Users\pfh3221\AppData\Local\Temp\ipykernel_4932\4252373756.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.pointplot(x="Condition", y="CorrectRejection", hue="Phenotype", data=tidy_df_clean, ci='sd', dodge=True, capsize=0.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the provided Excel file
file_path = 'DATA dSAT2.xlsx'

# Load the data from the 'Tidy' sheet
tidy_data = pd.read_excel(file_path, sheet_name='Tidy')

# Filter out the relevant columns for 'CR'
filtered_data = tidy_data[['Distractor_Condition', 'Phenotype', 'CR']]

# Calculate the mean and standard deviation of 'CR' for each combination of Distractor_Condition and Phenotype
summary_cr = filtered_data.groupby(['Distractor_Condition', 'Phenotype']).agg(
    mean_cr=('CR', 'mean'),
    std_cr=('CR', 'std')
).reset_index()

# Define the phenotype colors
phenotypes = {'ST': 'green', 'IN': 'orange', 'GT': 'red'}

# Set up the plot configuration for CR
plt.figure(figsize=(6, 6))

# Create the plot for 'CR' with mean and standard deviation
for phenotype, color in phenotypes.items():
    subset = summary_cr[summary_cr['Phenotype'] == phenotype]
    plt.errorbar(subset['Distractor_Condition'], subset['mean_cr'], yerr=subset['std_cr'], 
                 label=phenotype, color=color, marker='o', capsize=5)

plt.title('CR (Correct Rejections)')
plt.xlabel('Distractor Condition')
plt.ylabel('CR (Mean ± SD)')
plt.ylim(0, summary_cr['mean_cr'].max() + summary_cr['std_cr'].max() + 1)
plt.legend()

plt.tight_layout()
plt.show()
